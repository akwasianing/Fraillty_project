# %%
import pandas as pd
import numpy as np

# %%
# load frailty data (raw data)
df = pd.read_csv('https://raw.githubusercontent.com/akwasianing/Fraillty_project/refs/heads/main/data_raw/raw_frailty_data.csv', delimiter =';')
df
# Out:
#   Height  Weight  Age  Grip strength  Frailty
# 0   65.8     112   30             30        N
# 1   71.5     136   19             31        N
# 2   69.4     153   45             29        N
# 3   68.2     142   22             28        Y
# 4   67.8     144   29             24        Y
# 5   68.7     123   50             26        N
# 6   69.8     141   51             22        Y
# 7   70.1     136   23             20        Y
# 8   67.9     112   17             19        N
# 9   66.8     120   39             31        N

# %%
# clean frailty data
# checking for missing values
print(df.isnull().sum())

# Remove duplicate rows and Check for duplicate rows again
df.drop_duplicates(inplace=True)
print(df.duplicated().sum())
# Out:
# Height            0
# Weight            0
# Age               0
# Grip strength     0
# Frailty           0
# dtype: int64
# 0

# %%
df.to_csv("cleaned_data.csv", index=False)
